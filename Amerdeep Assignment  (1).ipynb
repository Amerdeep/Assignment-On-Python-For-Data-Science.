# %% [markdown]
# # Assignment On Python For Data Science.

# %% [markdown]
# ## Assignment Questions:

# %% [markdown]
# ### **Do the following operation on Iris dataset:**

# %% [markdown]
# 1. Read the dataset to python environment.
# 2. Display the columns in the dataset.
# 3. Calculate the mean of each column of the dataset.
# 4. Check for the null values present in the dataset.
# 5. Perform meaningful visualizations using the dataset.Bring at least 3 visualizations.

# %% [markdown]
# ## Solutions:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1st Question Answer (To Upload Data Into Python Enviornment)

# %%
#1. Read the dataset to python environment.
data=pd.read_excel(r"C:\Users\illca\Downloads\iris.xls")

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Data Studying

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.tail()
# Out:
#       SL   SW   PL   PW  Classification
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.value_counts("Classification")
# Out:
# Classification
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ### 2nd Question Answer (To Display Columns)

# %%
#2. Display the columns in the dataset.
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## Renaming the Columns To make it Easy To Understand

# %%
data=data.rename(columns={"SL":"Sepal_Length","SW":"Sepal_Width","PL": "Petal_Length","PW":"Petal_Width"})
data
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Classification
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 3rd Question Answer (To Display Mean Of Each Column)

# %%
#3. Calculate the mean of each column of the dataset.
data[["Sepal_Length","Sepal_Width","Petal_Length","Petal_Width"]].mean()
# Out:
# Sepal_Length    5.843333
# Sepal_Width     3.054000
# Petal_Length    3.758667
# Petal_Width     1.198667
# dtype: float64

# %% [markdown]
# ### 4rth Question Answer (To Display Null Values In The Data)

# %%
#4. Check for the null values present in the dataset.
data.isna()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Classification
# 0           False        False         False        False           False
# 1           False        False         False        False           False
# 2           False        False         False        False           False
# 3           False        False         False        False           False
# 4           False        False         False        False           False
# ..            ...          ...           ...          ...             ...
# 145         False        False         False        False           False
# 146         False        False         False        False           False
# 147         False        False         False        False           False
# 148         False        False         False        False           False
# 149         False        False         False        False           False
#
# [150 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# Sepal_Length      0
# Sepal_Width       0
# Petal_Length      0
# Petal_Width       0
# Classification    0
# dtype: int64

# %% [markdown]
# ### 5fth Question Answer (Data Visualization)

# %% [markdown]
# ## Count Plot

# %%
#5. Perform meaningful visualizations using the dataset.Bring at least 3 visualizations.
#1.

sns.countplot(x="Classification",data=data)
plt.show()

# %% [markdown]
# ## Pair Plot

# %%
#2.
sns.pairplot(data,hue="Classification")
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
#3.
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.scatter(data["Sepal_Length"],data["Petal_Length"],c="r",s=30,marker="^")
plt.title("Sepal Length vs Petal Length",fontsize=15)
plt.xlabel("Sepal Length",fontsize=15)
plt.ylabel("Petal Length",fontsize=15)
plt.subplot(2,2,2)
plt.scatter(data["Sepal_Length"],data["Petal_Width"],c="g",s=30)
plt.title("Sepal Length vs Petal Width",fontsize=15)
plt.xlabel("Sepal Length",fontsize=15)
plt.ylabel("Petal Width",fontsize=15)
plt.subplot(2,2,3)
plt.scatter(data["Sepal_Width"],data["Petal_Length"],c="k",s=30,marker="*")
plt.title("Sepal Width vs Petal Length",fontsize=15)
plt.xlabel("Sepal Width",fontsize=15)
plt.ylabel("Petal Length",fontsize=15)
plt.subplot(2,2,4)
plt.scatter(data["Sepal_Width"],data["Petal_Width"],c="orange",s=30,marker="+")
plt.title("Sepal Width vs Petal Width",fontsize=15)
plt.xlabel("Sepal Width",fontsize=15)
plt.ylabel("Petal Width",fontsize=15)
plt.tight_layout()

# %% [markdown]
# ## Heat Map

# %%
#4.
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>
